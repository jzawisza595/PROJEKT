# %% [markdown]
# <a href="https://colab.research.google.com/github/jzawisza595/PROJEKT/blob/main/inz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nowa sekcja

# %%
# !python model.py
# Out:
# 2024-05-29 10:13:35.532907: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-29 10:13:35.532967: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-29 10:13:35.534517: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-29 10:13:35.542929: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # Nowa sekcja

# %%
# !python predykcja.py
# Out:
# 2024-05-28 07:23:44.881717: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-28 07:23:44.881796: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-28 07:23:44.885825: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-28 07:23:44.905911: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python predykcja.py
# Out:
# 2024-05-28 07:25:54.614645: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-28 07:25:54.614719: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-28 07:25:54.617156: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-28 07:25:54.629982: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !zip -r project.zip /content/dane /content/sample_data /content/testowe /content/label_encoder.save /content/model.keras /content/model.py /content/predykcja.py /content/scaler.save /content/test.m
# Out:
#   adding: content/dane/ (stored 0%)
#   adding: content/dane/helikopter/ (stored 0%)
#   adding: content/dane/helikopter/heli2.csv (deflated 76%)
#   adding: content/dane/helikopter/heli5.csv (deflated 75%)
#   adding: content/dane/helikopter/heli3.csv (deflated 75%)
#   adding: content/dane/helikopter/.ipynb_checkpoints/ (stored 0%)
#   adding: content/dane/helikopter/heli1.csv (deflated 76%)
#   adding: content/dane/helikopter/heli4.csv (deflated 75%)
#   adding: content/dane/pasazerski/ (stored 0%)
#   adding: content/dane/pasazerski/pasazerski3.csv (deflated 73%)
#   adding: content/dane/pasazerski/.ipynb_checkpoints/ (stored 0%)
#   adding: content/dane/pasazerski/pasazerski1.csv (deflated 72%)
#   adding: content/dane/pasazerski/pasazerski2.csv (deflated 74%)
#   adding: content/dane/wojskowy/ (stored 0%)
#   adding: content/dane/wojskowy/wojskowy1.csv (deflated 72%)
#   adding: content/dane/wojskowy/wojskowy3.csv (deflated 75%)
# ...

# %%
from google.colab import files
files.download('project.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-290915891adb> in <cell line: 2>()
#       1 from google.colab import files
# ----> 2 files.download('project.zip')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: project.zip

# %%
# !git config --global user.name "Your Name"
